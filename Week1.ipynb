# %% [markdown]
# <a href="https://colab.research.google.com/github/jooharver/PCVK_Eka_Krisna_Ferian_TI-3D_2024/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#langkah 1
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

#langkah2

# membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg"]
       #"https://placekitten.com/800/571"]
# baca dan tampilkan image
#loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
        image = io.imread(url) #read image
        image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image
        image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB) #convert color BGR to RGB
        final_frame = cv.hconcat((image, image_2)) #concatenate image

        # langkah 3
        tinggi = image_2.shape[0]
        lebar = image_2.shape[1]
        print("resolusi image: tinggi x lebar =  ", tinggi, " x ", lebar)

        # langkah 4
        image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
        image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

        # membuat garis vertikal di tengah image
        #for x in range(tinggi):
          #image_3[x, int(lebar/2)] = [255, 255, 255]

        # membuat garis silang diagonal
        # Membuat garis diagonal dari sudut kiri atas ke sudut kanan bawah
        cv.line(image_3, (0, 0), (lebar-1, tinggi-1), (255, 255, 255), 1)

        # Membuat garis diagonal dari sudut kanan atas ke sudut kiri bawah
        cv.line(image_3, (lebar-1, 0), (0, tinggi-1), (255, 255, 255), 1)


        #membuat kotak
        # Menentukan koordinat sudut kiri atas dan sudut kanan bawah dari kotak
        # x1, y1 = 50, 50  # Koordinat sudut kiri atas
        # x2, y2 = 150, 150  # Koordinat sudut kanan bawah

        # Menggambar kotak putih di gambar
        cv.rectangle(image_3, (x1, y1), (x2, y2), (255, 255, 255), -1)  # -1 untuk mengisi kotak


        final_frame = cv.hconcat((image_2, image_3)) #concatenate image
        cv2_imshow(final_frame) #show image
        print('\n')
# Out:
# resolusi image: tinggi x lebar =   276  x  400
# <PIL.Image.Image image mode=RGB size=800x276>
# resolusi image: tinggi x lebar =   286  x  400
# <PIL.Image.Image image mode=RGB size=800x286>
