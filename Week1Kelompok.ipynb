# %% [markdown]
# <a href="https://colab.research.google.com/github/jooharver/PCVK_Eka_Krisna_Ferian_TI-3D_2024/blob/main/Week1Kelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
# Accessing Google Drive
drive.mount('/content/drive')
import cv2 as cv
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
# Step 1
img = cv.imread('/content/drive/MyDrive/PCVK/images/KTP7.jpeg')
# Convert BGR to RGB
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
x1 = 190
y1 = 65
x2 = 550
y2 = 98
x3 = 190
y3 = 280
x4 = 300
y4 = 300
for x in range(x1, x2):
  for y in range(y1, y2):
    img_rgb[y, x] = (255, 0, 0)
for x in range(x3, x4):
  for y in range(y3, y4):
    img_rgb[y, x] = (255, 255, 255)
# Display the image
plt.imshow(img_rgb)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
